# %%
#Program on AO* algorithm
def Cost(H, condition, weight = 1):
    cost = {}
    if 'AND' in condition:
        AND_nodes = condition['AND']
        Path_A = ' AND '.join(AND_nodes)
        PathA = sum(H[node]+weight for node in AND_nodes)
        cost[Path_A] = PathA

    if 'OR' in condition:
        OR_nodes = condition['OR']
        Path_B = ' OR '.join(OR_nodes)
        PathB = min(H[node]+weight for node in OR_nodes)
        cost[Path_B] = PathB
    return cost

def update_cost(H, Conditions, weight):
    Main_nodes = list(Conditions.keys())
    Main_nodes.reverse()
    least_cost = {}
    for key in Main_nodes:
        condition = Conditions[key]
        print('path cost for',key, ':', Conditions[key], '>>>', Cost(H, condition, weight))
        c = Cost(H, condition, weight)
        H[key] = min(c.values())
        least_cost[key] = Cost(H, condition, weight)
    print('\nPath with updated cost:',least_cost)
    return least_cost


def shortest_path(Start, Updated_cost, H):
    Path = Start
    if Start in Updated_cost.keys():
        Min_cost = min(Updated_cost[Start].values())
        key = list(Updated_cost[Start].keys())
        values = list(Updated_cost[Start].values())
        Index = values.index(Min_cost)

        Next = key[Index].split()

        if len(Next) == 1:
            Start = Next[0]
            Path += '<--' + shortest_path(Start, Updated_cost, H)

        else:
            Path += '<--('+key[Index]+':'+str(values[Index])+') '
            Start = Next[0]
            Path += '[' + shortest_path(Start, Updated_cost, H) + ' + '
            Start = Next[-1]
            Path += shortest_path(Start, Updated_cost, H) + ']'

    return Path

H = {'A': 0, 'B': 5, 'C': 2, 'D': 4, 'E': 7, 'F': 9, 'G': 3, 'H': 1, 'I': 1, 'J': 1}

Conditions = {
    'A': {'OR': ['B'], 'AND': ['C', 'D']},
    'B': {'OR': ['E', 'F']},
    'C': {'OR': ['G'], 'AND': ['H', 'I']},
    'D': {'OR': ['J']}
}
weight = 1

Updated_cost = update_cost(H, Conditions, weight)

print('\nShortest Path:\n', shortest_path('A', Updated_cost, H))
# Out:
# path cost for D : {'OR': ['J']} >>> {'J': 2}
# path cost for C : {'OR': ['G'], 'AND': ['H', 'I']} >>> {'H AND I': 4, 'G': 4}
# path cost for B : {'OR': ['E', 'F']} >>> {'E OR F': 8}
# path cost for A : {'OR': ['B'], 'AND': ['C', 'D']} >>> {'C AND D': 8, 'B': 9}
#
# Path with updated cost: {'D': {'J': 2}, 'C': {'H AND I': 4, 'G': 4}, 'B': {'E OR F': 8}, 'A': {'C AND D': 8, 'B': 9}}
#
# Shortest Path:
#  A<--(C AND D:8) [C<--(H AND I:4) [H + I] + D<--J]
