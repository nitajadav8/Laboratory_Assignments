# %%
#grey level transformation

# %%
import cv2
import numpy as np
import matplot.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6b559f97122d> in <cell line: 3>()
#       1 import cv2
#       2 import numpy as np
# ----> 3 import matplot.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
# !pip uninstall cv
# Out:
# Found existing installation: cv 1.0.0
# Uninstalling cv-1.0.0:
#   Would remove:
#     /usr/local/bin/cv
#     /usr/local/lib/python3.10/dist-packages/cv-1.0.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/cv.py
# Proceed (Y/n)? y
#   Successfully uninstalled cv-1.0.0

# %%
# !pip install opencv-python

# !pip install opencv-contrib-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread(r"/content/30th_birthday.png",1)
print("Type:",type(img))
print("Shape of Image:", img.shape)
print('Total Number of pixels:', img.size)
print("Image data type:", img.dtype)
print("Dimension:", img.ndim)
# Out:
# Type: <class 'numpy.ndarray'>
# Shape of Image: (764, 720, 3)
# Total Number of pixels: 1650240
# Image data type: uint8
# Dimension: 3

# %%
img=cv2.imread(r"/content/30th_birthday.png",1)

#negative
#img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#img_neg=cv2.bitwise_not(img)

#log
#c=255/np.log(1+np.max(img))
#img_log=c*(np.log(img+1))
#img_log=np.array(img_log, dtype=np.uint8)

#power-law
#g=0.6
#img_2=np.power(img, g)

fig, axis = plt.subplots(1, 2, figsize=(10, 3))
axis[0].imshow(img,cmap='gray')
axis[1].imshow(img_2, cmap='gray')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
